# %%
import csv
import pandas as pd

# %%
def one_table():
    data = []
    with open('tests/data/one_table/table.csv', 'r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        for row in csv_reader:
            data.append(row)
    return data


def one_table_result():
    with open('tests/data/one_table/test_data.json', 'r') as json_file:
        data = json.load(json_file)
    return data

# %%
one_table()
# Out:
# [{'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '517.0',
#   'sched_dep_time': '515',
#   'dep_delay': '2.0',
#   'arr_time': '830.0',
#   'sched_arr_time': '819',
#   'arr_delay': '11.0',
#   'carrier': 'UA',
#   'flight': '1545',
#   'tailnum': 'N14228',
#   'origin': 'EWR',
#   'dest': 'IAH',
#   'air_time': '227.0',
#   'distance': '1400',
#   'hour': '5',
#   'minute': '15',
#   'time_hour': '2013-01-01T10:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '533.0',
#   'sched_dep_time': '529',
#   'dep_delay': '4.0',
#   'arr_time': '850.0',
#   'sched_arr_time': '830',
#   'arr_delay': '20.0',
#   'carrier': 'UA',
#   'flight': '1714',
#   'tailnum': 'N24211',
#   'origin': 'LGA',
#   'dest': 'IAH',
#   'air_time': '227.0',
#   'distance': '1416',
#   'hour': '5',
#   'minute': '29',
#   'time_hour': '2013-01-01T10:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '542.0',
#   'sched_dep_time': '540',
#   'dep_delay': '2.0',
#   'arr_time': '923.0',
#   'sched_arr_time': '850',
#   'arr_delay': '33.0',
#   'carrier': 'AA',
#   'flight': '1141',
#   'tailnum': 'N619AA',
#   'origin': 'JFK',
#   'dest': 'MIA',
#   'air_time': '160.0',
#   'distance': '1089',
#   'hour': '5',
#   'minute': '40',
#   'time_hour': '2013-01-01T10:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '544.0',
#   'sched_dep_time': '545',
#   'dep_delay': '-1.0',
#   'arr_time': '1004.0',
#   'sched_arr_time': '1022',
#   'arr_delay': '-18.0',
#   'carrier': 'B6',
#   'flight': '725',
#   'tailnum': 'N804JB',
#   'origin': 'JFK',
#   'dest': 'BQN',
#   'air_time': '183.0',
#   'distance': '1576',
#   'hour': '5',
#   'minute': '45',
#   'time_hour': '2013-01-01T10:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '554.0',
#   'sched_dep_time': '600',
#   'dep_delay': '-6.0',
#   'arr_time': '812.0',
#   'sched_arr_time': '837',
#   'arr_delay': '-25.0',
#   'carrier': 'DL',
#   'flight': '461',
#   'tailnum': 'N668DN',
#   'origin': 'LGA',
#   'dest': 'ATL',
#   'air_time': '116.0',
#   'distance': '762',
#   'hour': '6',
#   'minute': '0',
#   'time_hour': '2013-01-01T11:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '554.0',
#   'sched_dep_time': '558',
#   'dep_delay': '-4.0',
#   'arr_time': '740.0',
#   'sched_arr_time': '728',
#   'arr_delay': '12.0',
#   'carrier': 'UA',
#   'flight': '1696',
#   'tailnum': 'N39463',
#   'origin': 'EWR',
#   'dest': 'ORD',
#   'air_time': '150.0',
#   'distance': '719',
#   'hour': '5',
#   'minute': '58',
#   'time_hour': '2013-01-01T10:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '555.0',
#   'sched_dep_time': '600',
#   'dep_delay': '-5.0',
#   'arr_time': '913.0',
#   'sched_arr_time': '854',
#   'arr_delay': '19.0',
#   'carrier': 'B6',
#   'flight': '507',
#   'tailnum': 'N516JB',
#   'origin': 'EWR',
#   'dest': 'FLL',
#   'air_time': '158.0',
#   'distance': '1065',
#   'hour': '6',
#   'minute': '0',
#   'time_hour': '2013-01-01T11:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '557.0',
#   'sched_dep_time': '600',
#   'dep_delay': '-3.0',
#   'arr_time': '709.0',
#   'sched_arr_time': '723',
#   'arr_delay': '-14.0',
#   'carrier': 'EV',
#   'flight': '5708',
#   'tailnum': 'N829AS',
#   'origin': 'LGA',
#   'dest': 'IAD',
#   'air_time': '53.0',
#   'distance': '229',
#   'hour': '6',
#   'minute': '0',
#   'time_hour': '2013-01-01T11:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '557.0',
#   'sched_dep_time': '600',
#   'dep_delay': '-3.0',
#   'arr_time': '838.0',
#   'sched_arr_time': '846',
#   'arr_delay': '-8.0',
#   'carrier': 'B6',
#   'flight': '79',
#   'tailnum': 'N593JB',
#   'origin': 'JFK',
#   'dest': 'MCO',
#   'air_time': '140.0',
#   'distance': '944',
#   'hour': '6',
#   'minute': '0',
#   'time_hour': '2013-01-01T11:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '558.0',
#   'sched_dep_time': '600',
#   'dep_delay': '-2.0',
#   'arr_time': '753.0',
#   'sched_arr_time': '745',
#   'arr_delay': '8.0',
#   'carrier': 'AA',
#   'flight': '301',
#   'tailnum': 'N3ALAA',
#   'origin': 'LGA',
#   'dest': 'ORD',
#   'air_time': '138.0',
#   'distance': '733',
#   'hour': '6',
#   'minute': '0',
#   'time_hour': '2013-01-01T11:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '558.0',
#   'sched_dep_time': '600',
#   'dep_delay': '-2.0',
#   'arr_time': '849.0',
#   'sched_arr_time': '851',
#   'arr_delay': '-2.0',
#   'carrier': 'B6',
#   'flight': '49',
#   'tailnum': 'N793JB',
#   'origin': 'JFK',
#   'dest': 'PBI',
#   'air_time': '149.0',
#   'distance': '1028',
#   'hour': '6',
#   'minute': '0',
#   'time_hour': '2013-01-01T11:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '558.0',
#   'sched_dep_time': '600',
#   'dep_delay': '-2.0',
#   'arr_time': '853.0',
#   'sched_arr_time': '856',
#   'arr_delay': '-3.0',
#   'carrier': 'B6',
#   'flight': '71',
#   'tailnum': 'N657JB',
#   'origin': 'JFK',
#   'dest': 'TPA',
#   'air_time': '158.0',
#   'distance': '1005',
#   'hour': '6',
#   'minute': '0',
#   'time_hour': '2013-01-01T11:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '558.0',
#   'sched_dep_time': '600',
#   'dep_delay': '-2.0',
#   'arr_time': '924.0',
#   'sched_arr_time': '917',
#   'arr_delay': '7.0',
#   'carrier': 'UA',
#   'flight': '194',
#   'tailnum': 'N29129',
#   'origin': 'JFK',
#   'dest': 'LAX',
#   'air_time': '345.0',
#   'distance': '2475',
#   'hour': '6',
#   'minute': '0',
#   'time_hour': '2013-01-01T11:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '558.0',
#   'sched_dep_time': '600',
#   'dep_delay': '-2.0',
#   'arr_time': '923.0',
#   'sched_arr_time': '937',
#   'arr_delay': '-14.0',
#   'carrier': 'UA',
#   'flight': '1124',
#   'tailnum': 'N53441',
#   'origin': 'EWR',
#   'dest': 'SFO',
#   'air_time': '361.0',
#   'distance': '2565',
#   'hour': '6',
#   'minute': '0',
#   'time_hour': '2013-01-01T11:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '559.0',
#   'sched_dep_time': '600',
#   'dep_delay': '-1.0',
#   'arr_time': '941.0',
#   'sched_arr_time': '910',
#   'arr_delay': '31.0',
#   'carrier': 'AA',
#   'flight': '707',
#   'tailnum': 'N3DUAA',
#   'origin': 'LGA',
#   'dest': 'DFW',
#   'air_time': '257.0',
#   'distance': '1389',
#   'hour': '6',
#   'minute': '0',
#   'time_hour': '2013-01-01T11:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '559.0',
#   'sched_dep_time': '559',
#   'dep_delay': '0.0',
#   'arr_time': '702.0',
#   'sched_arr_time': '706',
#   'arr_delay': '-4.0',
#   'carrier': 'B6',
#   'flight': '1806',
#   'tailnum': 'N708JB',
#   'origin': 'JFK',
#   'dest': 'BOS',
#   'air_time': '44.0',
#   'distance': '187',
#   'hour': '5',
#   'minute': '59',
#   'time_hour': '2013-01-01T10:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '559.0',
#   'sched_dep_time': '600',
#   'dep_delay': '-1.0',
#   'arr_time': '854.0',
#   'sched_arr_time': '902',
#   'arr_delay': '-8.0',
#   'carrier': 'U',
#   'flight': None,
#   'tailnum': None,
#   'origin': None,
#   'dest': None,
#   'air_time': None,
#   'distance': None,
#   'hour': None,
#   'minute': None,
#   'time_hour': None},
#  {'year': 'A',
#   'month': '1187',
#   'day': 'N76515',
#   'dep_time': 'EWR',
#   'sched_dep_time': 'LAS',
#   'dep_delay': '337.0',
#   'arr_time': '2227',
#   'sched_arr_time': '6',
#   'arr_delay': '0',
#   'carrier': '2013-01-01T11:00:00Z',
#   'flight': None,
#   'tailnum': None,
#   'origin': None,
#   'dest': None,
#   'air_time': None,
#   'distance': None,
#   'hour': None,
#   'minute': None,
#   'time_hour': None},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '600.0',
#   'sched_dep_time': '600',
#   'dep_delay': '0.0',
#   'arr_time': '851.0',
#   'sched_arr_time': '858',
#   'arr_delay': '-7.0',
#   'carrier': 'B6',
#   'flight': '371',
#   'tailnum': 'N595JB',
#   'origin': 'LGA',
#   'dest': 'FLL',
#   'air_time': '152.0',
#   'distance': '1076',
#   'hour': '6',
#   'minute': '0',
#   'time_hour': '2013-01-01T11:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '600.0',
#   'sched_dep_time': '600',
#   'dep_delay': '0.0',
#   'arr_time': '837.0',
#   'sched_arr_time': '825',
#   'arr_delay': '12.0',
#   'carrier': 'MQ',
#   'flight': '4650',
#   'tailnum': 'N542MQ',
#   'origin': 'LGA',
#   'dest': 'ATL',
#   'air_time': '134.0',
#   'distance': '762',
#   'hour': '6',
#   'minute': '0',
#   'time_hour': '2013-01-01T11:00:00Z'},
#  {'year': '2013',
#   'month': '1',
#   'day': '1',
#   'dep_time': '601.0',
#   'sched_dep_time': '600',
#   'dep_delay': '1.0',
#   'arr_time': '844.0',
#   'sched_arr_time': '850',
#   'arr_delay': '-6.0',
#   'carrier': 'B6',
#   'flight': '343',
#   'tailnum': 'N644JB',
#   'origin': 'EWR',
#   'dest': 'PBI',
#   'air_time': '147.0',
#   'distance': '1023',
#   'hour': '6',
#   'minute': '0',
#   'time_hour': '2013-01-01T11:00:00Z'}]

# %%
df = pd.read_csv('tests/data/one_table/table.csv')
df.to_json(orient='records')
# Out:
# '[{"year":"2013","month":1,"day":"1","dep_time":"517.0","sched_dep_time":"515","dep_delay":2.0,"arr_time":830.0,"sched_arr_time":819,"arr_delay":11.0,"carrier":"UA","flight":1545.0,"tailnum":"N14228","origin":"EWR","dest":"IAH","air_time":227.0,"distance":1400.0,"hour":5.0,"minute":15.0,"time_hour":"2013-01-01T10:00:00Z"},{"year":"2013","month":1,"day":"1","dep_time":"533.0","sched_dep_time":"529","dep_delay":4.0,"arr_time":850.0,"sched_arr_time":830,"arr_delay":20.0,"carrier":"UA","flight":1714.0,"tailnum":"N24211","origin":"LGA","dest":"IAH","air_time":227.0,"distance":1416.0,"hour":5.0,"minute":29.0,"time_hour":"2013-01-01T10:00:00Z"},{"year":"2013","month":1,"day":"1","dep_time":"542.0","sched_dep_time":"540","dep_delay":2.0,"arr_time":923.0,"sched_arr_time":850,"arr_delay":33.0,"carrier":"AA","flight":1141.0,"tailnum":"N619AA","origin":"JFK","dest":"MIA","air_time":160.0,"distance":1089.0,"hour":5.0,"minute":40.0,"time_hour":"2013-01-01T10:00:00Z"},{"year":"2013","month":1,"day":"1","dep_time":"544.0","sched_dep_time":"545","dep_delay":-1.0,"arr_time":1004.0,"sched_arr_time":1022,"arr_delay":-18.0,"carrier":"B6","flight":725.0,"tailnum":"N804JB","origin":"JFK","dest":"BQN","air_time":183.0,"distance":1576.0,"hour":5.0,"minute":45.0,"time_hour":"2013-01-01T10:00:00Z"},{"year":"2013","month":1,"day":"1","dep_time":"554.0","sched_dep_time":"600","dep_delay":-6.0,"arr_time":812.0,"sched_arr_time":837,"arr_delay":-25.0,"carrier":"DL","flight":461.0,"tailnum":"N668DN","origin":"LGA","dest":"ATL","air_time":116.0,"distance":762.0,"hour":6.0,"minute":0.0,"time_hour":"2013-01-01T11:00:00Z"},{"year":"2013","month":1,"day":"1","dep_time":"554.0","sched_dep_time":"558","dep_delay":-4.0,"arr_time":740.0,"sched_arr_time":728,"arr_delay":12.0,"carrier":"UA","flight":1696.0,"tailnum":"N39463","origin":"EWR","dest":"ORD","air_time":150.0,"distance":719.0,"hour":5.0,"minute":58.0,"time_hour":"2013-01-01T10:00:00Z"},{"year":"2013","month":1,"day":"1","dep_time":"555.0","sched_dep_time":"600","dep_delay":-5.0,"arr_time":913.0,"sched_arr_time":854,"arr_delay":19.0,"carrier":"B6","flight":507.0,"tailnum":"N516JB","origin":"EWR","dest":"FLL","air_time":158.0,"distance":1065.0,"hour":6.0,"minute":0.0,"time_hour":"2013-01-01T11:00:00Z"},{"year":"2013","month":1,"day":"1","dep_time":"557.0","sched_dep_time":"600","dep_delay":-3.0,"arr_time":709.0,"sched_arr_time":723,"arr_delay":-14.0,"carrier":"EV","flight":5708.0,"tailnum":"N829AS","origin":"LGA","dest":"IAD","air_time":53.0,"distance":229.0,"hour":6.0,"minute":0.0,"time_hour":"2013-01-01T11:00:00Z"},{"year":"2013","month":1,"day":"1","dep_time":"557.0","sched_dep_time":"600","dep_delay":-3.0,"arr_time":838.0,"sched_arr_time":846,"arr_delay":-8.0,"carrier":"B6","flight":79.0,"tailnum":"N593JB","origin":"JFK","dest":"MCO","air_time":140.0,"distance":944.0,"hour":6.0,"minute":0.0,"time_hour":"2013-01-01T11:00:00Z"},{"year":"2013","month":1,"day":"1","dep_time":"558.0","sched_dep_time":"600","dep_delay":-2.0,"arr_time":753.0,"sched_arr_time":745,"arr_delay":8.0,"carrier":"AA","flight":301.0,"tailnum":"N3ALAA","origin":"LGA","dest":"ORD","air_time":138.0,"distance":733.0,"hour":6.0,"minute":0.0,"time_hour":"2013-01-01T11:00:00Z"},{"year":"2013","month":1,"day":"1","dep_time":"558.0","sched_dep_time":"600","dep_delay":-2.0,"arr_time":849.0,"sched_arr_time":851,"arr_delay":-2.0,"carrier":"B6","flight":49.0,"tailnum":"N793JB","origin":"JFK","dest":"PBI","air_time":149.0,"distance":1028.0,"hour":6.0,"minute":0.0,"time_hour":"2013-01-01T11:00:00Z"},{"year":"2013","month":1,"day":"1","dep_time":"558.0","sched_dep_time":"600","dep_delay":-2.0,"arr_time":853.0,"sched_arr_time":856,"arr_delay":-3.0,"carrier":"B6","flight":71.0,"tailnum":"N657JB","origin":"JFK","dest":"TPA","air_time":158.0,"distance":1005.0,"hour":6.0,"minute":0.0,"time_hour":"2013-01-01T11:00:00Z"},{"year":"2013","month":1,"day":"1","dep_time":"558.0","sched_dep_time":"600","dep_delay":-2.0,"arr_time":924.0,"sched_arr_time":917,"arr_delay": ...
